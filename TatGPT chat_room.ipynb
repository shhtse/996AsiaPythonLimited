# %%
# ChatGPT project

# %%
# Reference:
# https://platform.openai.com/docs/api-reference/introduction?lang=python

# https://www.cnblogs.com/ghj1976/p/openaicompletioncreate-jie-kou-can-shu-shuo-ming.html

# %%
# import library & customize module

import openai  # openAI ChatGPT
import config as cf # Bearer token
from textwrap import wrap
import datetime
import tatAPI

from IPython.core.display import display, HTML
# Out:
# Traceback (most recent call last):
#
#   File ~/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3505 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[77], line 7
#     import tatAPI
#
#   File ~/Desktop/ChatGPT/tatAPI.py:19
#     display(HTML('<div></div>')
#             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# set api key
openai.api_key = cf.API_KEY

# %% [markdown]
# ![tatgor.jpg](attachment:tatgor.jpg)

# %%
prompt = "What is the consequence of lack of electricity ?"
# prompt = input("Enter your question here : ")  
chatToTat(prompt)
